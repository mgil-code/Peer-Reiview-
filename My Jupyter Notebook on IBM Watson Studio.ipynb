# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# <b> Mahala Gilbert <b>

# %% [markdown]
# Biostatistician

# %% [markdown]
# *I am interested in Data Science because I am interested in taking my degree in Biology and utilizing it towards building and runing statistical programs to help research efforts. I am interested in becoming a biostatistician because I feel like this is the best job that uses both my interest in comupter science and my passion for biology.*

# %% [markdown]
# ### The code in cell 5 is supposed to show how code is written to create an output.

# %%
2+3
# Out:
# 5

# %% [markdown]
# >Here is a block quote,
# ~~followed by a strike through~~
# ***
# - Bullet Point
# 1. Numbered list
#
# ```
#   Highlight
# ```
# https://www.mayoclinic.org/healthy-lifestyle/consumer-health/in-depth/mindfulness-exercises/art-20046356
#
# ![image.png](attachment:image.png)
